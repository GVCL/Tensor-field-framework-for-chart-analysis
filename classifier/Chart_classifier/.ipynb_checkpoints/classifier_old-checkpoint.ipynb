# %%
from PIL import Image # used for loading images
import numpy as np
import os, sys # used for navigating to image path
import imageio # used for writing images
import pandas as pd
import cv2
import numpy as np

import glob

# %%
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Activation
from keras.models import model_from_json
from keras.models import Sequential
from keras.utils import to_categorical


import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:469: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:470: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:471: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:472: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:473: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:476: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def resize_images(path):
    directory = path

    for file_name in os.listdir(directory):
      print("Processing %s" % file_name)
      image = Image.open(os.path.join(directory, file_name))

      x,y = image.size
      new_dimensions = (200, 200)
      output = image.resize(new_dimensions, Image.ANTIALIAS)

      output_file_name = os.path.join(directory, file_name)
      output.save(output_file_name, "PNG", quality = 100)

    print("All done")

# %%
path1 = "/home/komaldadhich/Documents/study/Research/graph_percept/source/project/chart-data-extraction/classifier/Chart_classifier/dataset2/train/bar"
path2 = "/home/komaldadhich/Documents/study/Research/graph_percept/source/project/chart-data-extraction/classifier/Chart_classifier/dataset2/train/scatterplot"
path3 = "/home/komaldadhich/Documents/study/Research/graph_percept/source/project/chart-data-extraction/classifier/Chart_classifier/dataset2/train/line"
path4 = "/home/komaldadhich/Documents/study/Research/graph_percept/source/project/chart-data-extraction/classifier/Chart_classifier/dataset2/train/pie"
resize_images(path1)
resize_images(path2)
resize_images(path3)
resize_images(path4)
# Out:
# Processing bar_91.png
# Processing bar_54.png
# Processing bar_18.png
# Processing bar_9.png
# Processing 00172.png
# Processing 00028.png
# Processing 00066.png
# Processing 00073.png
# Processing 00139.png
# Processing mark=bar|x=count_*,Q|y=Streptomycin,O|detail=Bacteria,N.png
# Processing bar_281.png
# Processing bar_99.png
# Processing 00036.png
# Processing 00055.png
# Processing bar_98.png
# Processing 00114.png
# Processing bar_175.png
# Processing 00016.png
# Processing 00188.png
# Processing bar_237.png
# Processing 00079.png
# Processing 00007.png
# Processing bar_243.png
# Processing 00077.png
# Processing bar_188.png
# Processing bar_131.png
# Processing 00129.png
# Processing 00183.png
# Processing bar_10.png
# Processing images.png
# Processing bar_203.png
# Processing bar_77.png
# Processing bar_227.png
# Processing 00091.png
# Processing 00169.png
# Processing 00026.png
# Processing 00043.png
# Processing bar_179.png
# Processing 00182.png
# Processing bar_264.png
# Processing 00179.png
# Processing 00086.png
# Processing bar_3.png
# Processing mark=bar|x=Neomycin,O|y=count_*,Q|color=Genus,N.png
# Processing bar_167.png
# Processing bar_255.png
# Processing 00162.png
# Processing bar_234.png
# Processing 00023.png
# Processing 00160.png
# Processing bar_222.png
# Processing 00064.png
# Processing bar_123.png
# Processing bar_201.png
# Processing bar_29.png
# Processing bar_41.png
# Processing 00151.png
# Processing bar_286.png
# Processing 00102.png
# Processing bar_110.png
# Processing bar_247.png
# Processing 00156.png
# Processing bar_209.png
# Processing bar_72.png
# Processing 00126.png
# Processing bar_89.png
# Processing bar_137.png
# Processing 00083.png
# Processing bar_202.png
# Processing bar_212.png
# Processing bar_88.png
# Processing 00099.png
# Processing 00127.png
# Processing 00044.png
# Processing 00134.png
# Processing 00164.png
# Processing bar_57.png
# Processing 00154.png
# Processing bar_103.png
# Processing mark=bar|x=count_*,Q|y=Penicilin,O|color=Neomycin,O.png
# Processing images (7).png
# Processing bar_251.png
# Processing 00171.png
# Processing images (12).png
# Processing bar_230.png
# Processing bar_158.png
# Processing images (1).jpeg
# Processing 00121.png
# Processing bar_136.png
# Processing bar_157.png
# Processing bar_23.png
# Processing bar_271.png
# Processing download (2).png
# Processing bar_217.png
# Processing bar_214.png
# Processing 00010.png
# Processing bar_192.png
# Processing 00053.png
# Processing 00019.png
# Processing bar_296.png
# Processing 00084.png
# Processing 00165.png
# Processing bar_283.png
# Processing 00192.png
# Processing bar_50.png
# Processing 00189.png
# Processing 00177.png
# Processing bar_143.png
# Processing bar_272.png
# Processing bar_40.png
# Processing 00143.png
# Processing bar_142.png
# Processing 00067.png
# Processing 00078.png
# Processing 00093.png
# Processing 00087.png
# Processing 00052.png
# Processing mark=bar|x=Bacteria,N|y=mean_Neomycin,Q.png
# Processing 00103.png
# Processing 00176.png
# Processing bar_162.png
# Processing bar_287.png
# Processing bar_180.png
# Processing bar_274.png
# Processing bar_144.png
# Processing bar_156.png
# Processing bar_109.png
# Processing bar_147.png
# Processing bar_27.png
# Processing bar_92.png
# Processing images (4).png
# Processing bar_184.png
# Processing bar_236.png
# Processing bar_25.png
# Processing bar_28.png
# Processing bar_139.png
# Processing 00167.png
# Processing 00138.png
# Processing bar_228.png
# Processing mark=bar|x=Streptomycin,O|y=count_*,Q|color=Gram_Staining,N.png
# Processing bar_244.png
# Processing bar_7.png
# Processing bar_242.png
# Processing bar_53.png
# Processing bar_146.png
# Processing bar_295.png
# Processing bar_64.png
# Processing bar_231.png
# Processing bar_62.png
# Processing bar_282.png
# Processing 00088.png
# Processing bar_178.png
# Processing bar_216.png
# Processing bar_33.png
# Processing bar_100.png
# Processing 00017.png
# Processing bar_232.png
# Processing 00004.png
# Processing bar_248.png
# Processing bar_277.png
# Processing 00130.png
# Processing images (8).png
# Processing bar_31.png
# Processing 00125.png
# Processing bar_105.png
# Processing 00170.png
# Processing 00039.png
# Processing bar_52.png
# Processing bar_26.png
# Processing 00157.png
# Processing 00109.png
# Processing 00190.png
# Processing bar_148.png
# Processing bar_65.png
# Processing images (19).png
# Processing bar_69.png
# Processing bar_279.png
# Processing bar_87.png
# Processing 00153.png
# Processing mark=bar|x=count_*,Q|y=Neomycin,O|color=Gram_Staining,N.png
# Processing bar_2.png
# Processing bar_42.png
# Processing mark=bar|x=Streptomycin,O|y=count_*,Q|color=Genus,N.png
# Processing bar_275.png
# Processing bar_95.png
# Processing 00186.png
# Processing 00035.png
# Processing mark=bar|x=Bacteria,N|y=mean_Streptomycin,Q.png
# Processing bar_165.png
# Processing 00011.png
# Processing bar_252.png
# Processing bar_206.png
# Processing bar_22.png
# Processing 00140.png
# Processing 00144.png
# Processing bar_61.png
# Processing bar_116.png
# Processing bar_170.png
# Processing bar_16.png
# Processing bar_220.png
# Processing 00166.png
# Processing bar_47.png
# Processing 00081.png
# Processing 00090.png
# Processing bar_134.png
# Processing images.jpeg
# Processing mark=bar|x=Genus,N|y=count_*,Q|color=Streptomycin,O.png
# Processing 00098.png
# Processing images (18).png
# Processing images (13).png
# Processing bar_294.png
# Processing 00089.png
# Processing bar_240.png
# Processing bar_189.png
# Processing bar_164.png
# Processing bar_290.png
# Processing bar_210.png
# Processing 00072.png
# Processing bar_208.png
# Processing download.png
# Processing bar_66.png
# Processing bar_124.png
# Processing bar_129.png
# Processing bar_4.png
# Processing bar_130.png
# Processing bar_169.png
# Processing bar_73.png
# Processing bar_19.png
# Processing 00119.png
# Processing 00013.png
# Processing bar_265.png
# Processing bar_241.png
# Processing bar_256.png
# Processing bar_112.png
# Processing 00163.png
# Processing bar_76.png
# Processing bar_153.png
# Processing bar_135.png
# Processing bar_46.png
# Processing bar_268.png
# Processing bar_160.png
# Processing images (23).png
# Processing bar_6.png
# Processing bar_45.png
# Processing bar_260.png
# Processing bar_249.png
# Processing 00048.png
# Processing bar_119.png
# Processing 00080.png
# Processing bar_257.png
# Processing bar_107.png
# Processing bar_185.png
# Processing 00015.png
# Processing images (2).png
# Processing bar_229.png
# Processing 00051.png
# Processing bar_113.png
# Processing bar_48.png
# Processing bar_132.png
# Processing 00060.png
# Processing mark=bar|x=count_*,Q|y=Genus,N.png
# Processing images (24).png
# Processing 00100.png
# Processing bar_24.png
# Processing 00074.png
# Processing bar_155.png
# Processing bar_176.png
# Processing bar_163.png
# Processing bar_12.png
# Processing 00180.png
# Processing 00021.png
# Processing 00050.png
# Processing bar_284.png
# Processing bar_224.png
# Processing bar_280.png
# Processing 00032.png
# Processing 00071.png
# Processing 00096.png
# Processing 00173.png
# Processing 00054.png
# Processing bar_32.png
# Processing bar_63.png
# Processing bar_299.png
# Processing mark=bar|x=count_*,Q|y=Penicilin,O|color=Genus,N.png
# Processing 00038.png
# Processing 00056.png
# Processing bar_20.png
# Processing bar_58.png
# Processing bar_239.png
# Processing 00105.png
# Processing 00001.png
# Processing bar_267.png
# Processing bar_11.png
# Processing bar_298.png
# Processing bar_34.png
# Processing images (14).png
# Processing bar_276.png
# Processing bar_183.png
# Processing bar_67.png
# Processing bar_211.png
# Processing 00082.png
# Processing bar_37.png
# Processing bar_246.png
# Processing mark=bar|x=count_*,Q|y=Genus,N|detail=Penicilin,O.png
# Processing bar_35.png
# Processing bar_262.png
# Processing bar_200.png
# Processing bar_114.png
# Processing 00122.png
# Processing bar_17.png
# Processing bar_56.png
# Processing bar_133.png
# Processing bar_104.png
# Processing bar_59.png
# Processing bar_83.png
# Processing 00185.png
# Processing mark=bar|x=Genus,N|y=count_*,Q|detail=Gram_Staining,N.png
# Processing bar_78.png
# Processing bar_168.png
# Processing bar_120.png
# Processing bar_161.png
# Processing bar_75.png
# Processing 00113.png
# Processing bar_97.png
# Processing 00152.png
# Processing 00101.png
# Processing bar_150.png
# Processing mark=bar|x=count_*,Q|y=Penicilin,O|color=Bacteria,N.png
# Processing bar_269.png
# Processing bar_138.png
# Processing 00120.png
# Processing bar_196.png
# Processing bar_140.png
# Processing 00005.png
# Processing images (21).png
# Processing 00142.png
# Processing mark=bar|x=Neomycin,O|y=count_*,Q|color=Gram_Staining,N.png
# Processing 00106.png
# Processing bar_254.png
# Processing bar_30.png
# Processing bar_159.png
# Processing bar_238.png
# Processing 00123.png
# Processing 00008.png
# Processing 00029.png
# Processing bar_198.png
# Processing 00146.png
# Processing 00095.png
# Processing 00020.png
# Processing bar_44.png
# Processing images (15).png
# Processing bar_117.png
# Processing bar_1.png
# Processing images (16).png
# Processing bar_235.png
# Processing 00135.png
# Processing bar_8.png
# Processing bar_181.png
# Processing bar_55.png
# Processing bar_84.png
# Processing images (11).png
# Processing bar_194.png
# Processing bar_197.png
# Processing bar_14.png
# Processing bar_86.png
# Processing 00025.png
# Processing bar_207.png
# Processing 00111.png
# Processing bar_204.png
# Processing bar_219.png
# Processing 00040.png
# Processing bar_223.png
# Processing 00158.png
# Processing 00031.png
# Processing bar_177.png
# Processing 00094.png
# Processing bar_253.png
# Processing 00137.png
# Processing bar_81.png
# Processing bar_15.png
# Processing bar_149.png
# Processing bar_225.png
# Processing images (6).png
# Processing bar_85.png
# Processing 00014.png
# Processing bar_74.png
# Processing mark=bar|x=count_*,Q|y=Penicilin,O|color=Gram_Staining,N.png
# Processing bar_39.png
# Processing bar_174.png
# Processing bar_38.png
# Processing bar_141.png
# Processing bar_266.png
# Processing 00132.png
# Processing bar_118.png
# Processing bar_127.png
# Processing 00191.png
# Processing images (9).png
# Processing mark=bar|x=Genus,N|y=count_*,Q|detail=Bacteria,N.png
# Processing bar_171.png
# Processing 00041.png
# Processing bar_250.png
# Processing bar_145.png
# Processing bar_125.png
# Processing 00174.png
# Processing bar_108.png
# Processing bar_278.png
# Processing images (25).png
# Processing 00076.png
# Processing images (10).png
# Processing bar_205.png
# Processing 00042.png
# Processing 00037.png
# Processing 00131.png
# Processing 00063.png
# Processing 00155.png
# Processing bar_79.png
# Processing 00046.png
# Processing bar_43.png
# Processing 00062.png
# Processing bar_213.png
# Processing bar_233.png
# Processing bar_199.png
# Processing 00116.png
# Processing bar_186.png
# Processing bar_70.png
# Processing mark=bar|x=count_*,Q|y=Streptomycin,O|detail=Genus,N.png
# Processing bar_297.png
# Processing bar_218.png
# Processing bar_82.png
# Processing 00112.png
# Processing bar_173.png
# Processing bar_293.png
# Processing bar_292.png
# Processing mark=bar|x=count_*,Q|y=Genus,N|detail=Neomycin,O.png
# Processing bar_261.png
# Processing images (22).png
# Processing bar_191.png
# Processing mark=bar|x=count_*,Q|y=Neomycin,O|color=Genus,N.png
# Processing 00107.png
# Processing 00124.png
# Processing bar_151.png
# Processing bar_121.png
# Processing bar_126.png
# Processing 00141.png
# Processing bar_80.png
# Processing bar_263.png
# Processing bar_115.png
# Processing bar_90.png
# Processing 00118.png
# Processing 00097.png
# Processing images (20).png
# Processing 00168.png
# Processing bar_215.png
# Processing bar_190.png
# Processing bar_101.png
# Processing 00068.png
# Processing bar_187.png
# Processing bar_270.png
# Processing bar_259.png
# Processing 00049.png
# Processing bar_182.png
# Processing bar_166.png
# Processing download (1).png
# Processing bar_154.png
# Processing bar_51.png
# Processing bar_128.png
# Processing 00085.png
# Processing bar_273.png
# Processing bar_21.png
# Processing images (5).png
# Processing bar_226.png
# Processing bar_36.png
# Processing bar_96.png
# Processing mark=bar|x=count_*,Q|y=Streptomycin,O|color=Genus,N.png
# Processing bar_245.png
# Processing bar_289.png
# Processing 00159.png
# Processing images (3).png
# Processing 00057.png
# Processing images (1).png
# Processing bar_49.png
# Processing bar_102.png
# Processing bar_111.png
# Processing bar_172.png
# Processing bar_258.png
# Processing 00117.png
# Processing mark=bar|x=count_*,Q|y=Streptomycin,O|color=Neomycin,O.png
# Processing 00184.png
# Processing mark=bar|x=count_*,Q|y=Neomycin,O.png
# Processing bar_13.png
# Processing 00187.png
# Processing 00034.png
# Processing bar_195.png
# Processing bar_285.png
# Processing 00092.png
# Processing 00149.png
# Processing bar_221.png
# Processing 00058.png
# Processing 00161.png
# Processing bar_68.png
# Processing bar_93.png
# Processing 00065.png
# Processing 00128.png
# Processing bar_71.png
# Processing bar_106.png
# Processing images (17).png
# Processing bar_291.png
# Processing bar_94.png
# Processing bar_5.png
# Processing 00075.png
# Processing 00070.png
# Processing bar_122.png
# Processing bar_0.png
# Processing mark=bar|x=Neomycin,O|y=count_*,Q|color=Penicilin,O.png
# Processing 00147.png
# Processing 00000.png
# Processing bar_288.png
# Processing bar_193.png
# Processing 00181.png
# Processing 00045.png
# Processing 00133.png
# Processing bar_152.png
# Processing mark=bar|x=Bacteria,N|y=mean_Penicilin,Q.png
# Processing bar_60.png
# All done
# Processing 00367.png
# Processing 00172.png
# Processing 00277.png
# Processing 2D-scatter_150.png
# Processing 00028.png
# Processing 00066.png
# Processing 2D-scatter_54.png
# Processing 00073.png
# Processing 00139.png
# Processing 2D-scatter_79.png
# Processing 00303.png
# Processing 2D-scatter_62.png
# Processing 00276.png
# Processing 00302.png
# Processing 00036.png
# Processing 2D-scatter_97.png
# Processing 00055.png
# Processing 00114.png
# Processing 00016.png
# Processing 00188.png
# Processing 00079.png
# Processing 00261.png
# Processing 2D-scatter_56.png
# Processing 00328.png
# Processing 00322.png
# Processing 00352.png
# Processing 00007.png
# Processing 00305.png
# Processing 00077.png
# Processing 00219.png
# Processing 2D-scatter_8.png
# Processing 00129.png
# Processing 00248.png
# Processing 00183.png
# Processing 2D-scatter_15.png
# Processing 2D-scatter_100.png
# Processing 00370.png
# Processing 00350.png
# Processing 2D-scatter_5.png
# Processing 2D-scatter_93.png
# Processing 00208.png
# Processing 00091.png
# Processing 00169.png
# Processing 00297.png
# Processing 2D-scatter_144.png
# Processing 2D-scatter_148.png
# Processing 00236.png
# Processing 00026.png
# Processing 00043.png
# Processing 2D-scatter_49.png
# Processing 00182.png
# Processing 00230.png
# Processing 00222.png
# Processing 00108.png
# Processing 00348.png
# Processing 00179.png
# Processing 2D-scatter_40.png
# Processing 00206.png
# Processing 00086.png
# Processing 2D-scatter_104.png
# Processing 2D-scatter_92.png
# Processing 2D-scatter_86.png
# Processing 00286.png
# Processing 00003.png
# Processing 00162.png
# Processing 00023.png
# Processing 00160.png
# Processing 00178.png
# Processing 2D-scatter_88.png
# Processing 2D-scatter_7.png
# Processing 00064.png
# Processing 00296.png
# Processing 2D-scatter_83.png
# Processing 00368.png
# Processing 2D-scatter_37.png
# Processing 00151.png
# Processing 00102.png
# Processing 00156.png
# Processing 00310.png
# Processing 00126.png
# Processing 00047.png
# Processing 2D-scatter_87.png
# Processing 00083.png
# Processing 2D-scatter_46.png
# Processing 2D-scatter_121.png
# Processing 00099.png
# Processing 00127.png
# Processing 00044.png
# Processing 00287.png
# Processing 2D-scatter_76.png
# Processing 00134.png
# Processing 00337.png
# Processing 2D-scatter_123.png
# Processing 00164.png
# Processing 00154.png
# Processing 2D-scatter_115.png
# Processing 2D-scatter_36.png
# Processing 2D-scatter_119.png
# Processing 2D-scatter_99.png
# Processing 00171.png
# Processing 00282.png
# Processing 00320.png
# Processing 00213.png
# Processing 2D-scatter_139.png
# Processing 00193.png
# Processing 2D-scatter_75.png
# Processing 00255.png
# Processing 00358.png
# Processing 00150.png
# Processing 2D-scatter_35.png
# Processing 00121.png
# Processing 00281.png
# Processing 00237.png
# Processing 00203.png
# Processing 00010.png
# Processing 00333.png
# Processing 00357.png
# Processing 00053.png
# Processing 00019.png
# Processing 2D-scatter_134.png
# Processing 00084.png
# Processing 00165.png
# Processing 00192.png
# Processing 00189.png
# Processing 2D-scatter_81.png
# Processing mark=point|x=Bacteria,N|y=Streptomycin,O|detail=count_*,Q.png
# Processing 2D-scatter_18.png
# Processing 00177.png
# Processing 2D-scatter_34.png
# Processing 2D-scatter_44.png
# Processing 00143.png
# Processing 00231.png
# Processing 00329.png
# Processing 2D-scatter_89.png
# Processing 00215.png
# Processing 2D-scatter_21.png
# Processing 00326.png
# Processing 00067.png
# Processing 00078.png
# Processing 00093.png
# Processing 2D-scatter_52.png
# Processing 00087.png
# Processing 00052.png
# Processing 00103.png
# Processing 00176.png
# Processing 00018.png
# Processing 2D-scatter_73.png
# Processing 00216.png
# Processing 00283.png
# Processing 2D-scatter_124.png
# Processing 00194.png
# Processing mark=point|x=count_*,Q|y=Neomycin,O.png
# Processing 00300.png
# Processing 00022.png
# Processing 2D-scatter_113.png
# Processing 00356.png
# Processing 00252.png
# Processing 00267.png
# Processing 00200.png
# Processing 2D-scatter_109.png
# Processing 2D-scatter_57.png
# Processing 00293.png
# Processing 2D-scatter_41.png
# Processing 00345.png
# Processing 00241.png
# Processing 00167.png
# Processing 2D-scatter_106.png
# Processing 00319.png
# Processing 00138.png
# Processing 00006.png
# Processing 00311.png
# Processing 00308.png
# Processing 00349.png
# Processing 00088.png
# Processing mark=point|x=Gram_Staining,N|y=Genus,N|detail=count_*,Q.png
# Processing 2D-scatter_67.png
# Processing 00017.png
# Processing 00227.png
# Processing 00004.png
# Processing 00130.png
# Processing 00027.png
# Processing 2D-scatter_128.png
# Processing mark=point|x=Bacteria,N|y=Genus,N|detail=count_*,Q.png
# Processing 00125.png
# Processing 00195.png
# Processing 00170.png
# Processing 00039.png
# Processing 00157.png
# Processing 00109.png
# Processing 00190.png
# Processing mark=point|x=Bacteria,N|y=mean_Streptomycin,Q.png
# Processing 2D-scatter_4.png
# Processing 2D-scatter_20.png
# Processing 2D-scatter_138.png
# Processing 2D-scatter_132.png
# Processing 00153.png
# Processing 00249.png
# Processing 2D-scatter_28.png
# Processing 00207.png
# Processing 2D-scatter_68.png
# Processing 00186.png
# Processing 00197.png
# Processing 00035.png
# Processing 00011.png
# Processing 00340.png
# Processing 00235.png
# Processing 2D-scatter_55.png
# Processing 00140.png
# Processing 00145.png
# Processing 00144.png
# Processing 00292.png
# Processing 2D-scatter_70.png
# Processing mark=point|x=Bacteria,N|y=Gram_Staining,N|detail=count_*,Q.png
# Processing 00351.png
# Processing 00295.png
# Processing 2D-scatter_1.png
# Processing 00316.png
# Processing 2D-scatter_77.png
# Processing 00166.png
# Processing 00344.png
# Processing 00081.png
# Processing 2D-scatter_25.png
# Processing 00090.png
# Processing 00229.png
# Processing 00284.png
# Processing 00262.png
# Processing 00336.png
# Processing 00353.png
# Processing 2D-scatter_131.png
# Processing 00098.png
# Processing 00301.png
# Processing 00364.png
# Processing 2D-scatter_120.png
# Processing 00291.png
# Processing 00089.png
# Processing 2D-scatter_61.png
# Processing 00072.png
# Processing 00263.png
# Processing 00339.png
# Processing 2D-scatter_58.png
# Processing 00354.png
# Processing 2D-scatter_149.png
# Processing mark=point|x=Bacteria,N|y=count_*,Q.png
# Processing 2D-scatter_137.png
# Processing 00214.png
# Processing 2D-scatter_130.png
# Processing 00119.png
# Processing 00254.png
# Processing 00013.png
# Processing 00069.png
# Processing 2D-scatter_105.png
# Processing 2D-scatter_147.png
# Processing 2D-scatter_140.png
# Processing 00224.png
# Processing 00304.png
# Processing 00175.png
# Processing 2D-scatter_82.png
# Processing 2D-scatter_107.png
# Processing 00163.png
# Processing 00294.png
# Processing 2D-scatter_12.png
# Processing 00002.png
# Processing 2D-scatter_71.png
# Processing 00048.png
# Processing 00233.png
# Processing 00247.png
# Processing 00080.png
# Processing 2D-scatter_142.png
# Processing 2D-scatter_27.png
# Processing 00015.png
# Processing 00051.png
# Processing 00221.png
# Processing 00226.png
# Processing 00299.png
# Processing 00332.png
# Processing 00239.png
# Processing 00330.png
# Processing 2D-scatter_127.png
# Processing 2D-scatter_102.png
# Processing 2D-scatter_26.png
# Processing 00274.png
# Processing 00290.png
# Processing 00060.png
# Processing 00343.png
# Processing 2D-scatter_101.png
# Processing 00205.png
# Processing 2D-scatter_80.png
# Processing 00100.png
# Processing 00074.png
# Processing 2D-scatter_114.png
# Processing 00180.png
# Processing 00021.png
# Processing 00050.png
# Processing 2D-scatter_72.png
# Processing 2D-scatter_98.png
# Processing 00270.png
# Processing 00104.png
# Processing 00032.png
# Processing 00363.png
# Processing 00071.png
# Processing 00096.png
# Processing 2D-scatter_59.png
# Processing 00173.png
# Processing 00054.png
# Processing 2D-scatter_143.png
# Processing 00148.png
# Processing 00024.png
# Processing 2D-scatter_116.png
# Processing 00038.png
# Processing 2D-scatter_122.png
# Processing 00056.png
# Processing 2D-scatter_91.png
# Processing 00240.png
# Processing 00105.png
# Processing 00258.png
# Processing 00009.png
# Processing mark=point|x=count_*,Q|y=Neomycin,O|shape=Gram_Staining,N.png
# Processing 00001.png
# Processing 2D-scatter_23.png
# Processing mark=point|x=Bacteria,N|y=Penicilin,Q.png
# Processing 00325.png
# Processing 00359.png
# Processing 00317.png
# Processing 00082.png
# Processing 2D-scatter_133.png
# Processing 00257.png
# Processing 2D-scatter_30.png
# Processing 2D-scatter_13.png
# Processing 2D-scatter_22.png
# Processing 2D-scatter_0.png
# Processing 00202.png
# Processing 00122.png
# Processing mark=point|x=Genus,N|y=count_*,Q|detail=Penicilin,O.png
# Processing 00030.png
# Processing 00265.png
# Processing 00315.png
# Processing 2D-scatter_94.png
# Processing 2D-scatter_33.png
# Processing 00313.png
# Processing 00185.png
# Processing 00223.png
# Processing 00256.png
# Processing 00218.png
# Processing 2D-scatter_64.png
# Processing 00113.png
# Processing 00279.png
# Processing 00152.png
# Processing 00101.png
# Processing 00220.png
# Processing 00212.png
# Processing 2D-scatter_90.png
# Processing 00314.png
# Processing 00120.png
# Processing 00059.png
# Processing 2D-scatter_95.png
# Processing 2D-scatter_66.png
# Processing 2D-scatter_11.png
# Processing 00005.png
# Processing 00142.png
# Processing 00106.png
# Processing 2D-scatter_110.png
# Processing mark=point|x=Genus,N|y=Gram_Staining,N|color=count_*,Q.png
# Processing 2D-scatter_111.png
# Processing 00204.png
# Processing 00123.png
# Processing 00008.png
# Processing 00029.png
# Processing 00266.png
# Processing 2D-scatter_32.png
# Processing 00110.png
# Processing 00225.png
# Processing 00250.png
# Processing 00199.png
# Processing 00242.png
# Processing 00365.png
# Processing 00146.png
# Processing 00095.png
# Processing 00020.png
# Processing 00324.png
# Processing 00338.png
# Processing 00361.png
# Processing 2D-scatter_63.png
# Processing 00135.png
# Processing 2D-scatter_146.png
# Processing 2D-scatter_43.png
# Processing 2D-scatter_117.png
# Processing 00136.png
# Processing 00318.png
# Processing 2D-scatter_16.png
# Processing mark=point|x=Bacteria,N|y=Penicilin,O|detail=count_*,Q.png
# Processing 00025.png
# Processing 00111.png
# Processing 00040.png
# Processing 00158.png
# Processing 00341.png
# Processing 00031.png
# Processing 00269.png
# Processing 00309.png
# Processing 00094.png
# Processing 2D-scatter_108.png
# Processing 00137.png
# Processing 2D-scatter_136.png
# Processing 2D-scatter_17.png
# Processing 00280.png
# Processing 00014.png
# Processing 2D-scatter_47.png
# Processing 00246.png
# Processing 2D-scatter_38.png
# Processing 2D-scatter_69.png
# Processing 00264.png
# Processing 00362.png
# Processing 00331.png
# Processing 2D-scatter_74.png
# Processing 00132.png
# Processing 00347.png
# Processing mark=point|x=Bacteria,N|y=mean_Penicilin,Q.png
# Processing 00211.png
# Processing 00191.png
# Processing 00288.png
# Processing 00323.png
# Processing 00228.png
# Processing 00041.png
# Processing 00174.png
# Processing 00076.png
# Processing 2D-scatter_6.png
# Processing 00259.png
# Processing 00278.png
# Processing 00268.png
# Processing 00209.png
# Processing 00042.png
# Processing 00245.png
# Processing 00037.png
# Processing 00275.png
# Processing 00307.png
# Processing 00234.png
# Processing 00196.png
# Processing 00131.png
# Processing 00063.png
# Processing 00155.png
# Processing mark=point|x=Genus,N|y=count_*,Q|shape=Gram_Staining,N.png
# Processing 00012.png
# Processing 00046.png
# Processing 00062.png
# Processing 2D-scatter_53.png
# Processing 00369.png
# Processing 2D-scatter_39.png
# Processing 00116.png
# Processing 2D-scatter_3.png
# Processing 00366.png
# Processing 00198.png
# Processing 00112.png
# Processing 2D-scatter_141.png
# Processing 2D-scatter_42.png
# Processing 00243.png
# Processing 2D-scatter_50.png
# Processing 00107.png
# Processing 2D-scatter_103.png
# Processing 00124.png
# Processing 2D-scatter_2.png
# Processing 00271.png
# Processing 00141.png
# Processing 2D-scatter_19.png
# Processing 00232.png
# Processing mark=point|x=Bacteria,N|y=Neomycin,O|detail=count_*,Q.png
# Processing 00118.png
# Processing 00097.png
# Processing 2D-scatter_29.png
# Processing 2D-scatter_45.png
# Processing 2D-scatter_112.png
# Processing 00168.png
# Processing 00321.png
# Processing 2D-scatter_78.png
# Processing 00061.png
# Processing 2D-scatter_51.png
# Processing 00335.png
# Processing 00253.png
# Processing 00210.png
# Processing 00068.png
# Processing 00342.png
# Processing 00033.png
# Processing 2D-scatter_31.png
# Processing 00049.png
# Processing 2D-scatter_10.png
# Processing 2D-scatter_48.png
# Processing 2D-scatter_125.png
# Processing mark=point|x=Bacteria,N|y=Streptomycin,Q.png
# Processing 00085.png
# Processing 00298.png
# Processing 2D-scatter_126.png
# Processing 00272.png
# Processing 00159.png
# Processing 00334.png
# Processing 2D-scatter_24.png
# Processing 2D-scatter_60.png
# Processing 00057.png
# Processing 2D-scatter_96.png
# Processing 00360.png
# Processing 00260.png
# Processing 00117.png
# Processing 00285.png
# Processing 2D-scatter_135.png
# Processing 00238.png
# Processing 00244.png
# Processing 00273.png
# Processing 00115.png
# Processing 00184.png
# Processing 00187.png
# Processing 00034.png
# Processing 2D-scatter_85.png
# Processing 00092.png
# Processing 00217.png
# Processing 00149.png
# Processing 00058.png
# Processing 2D-scatter_129.png
# Processing 00161.png
# Processing 00346.png
# Processing mark=point|x=Bacteria,N|y=mean_Neomycin,Q.png
# Processing 00065.png
# Processing 00128.png
# Processing 00355.png
# Processing 2D-scatter_65.png
# Processing 2D-scatter_145.png
# Processing 2D-scatter_118.png
# Processing 2D-scatter_14.png
# Processing 00327.png
# Processing 00306.png
# Processing 00075.png
# Processing 00070.png
# Processing 00312.png
# Processing 00251.png
# Processing 00147.png
# Processing 00371.png
# Processing mark=point|x=count_*,Q|y=Penicilin,O.png
# Processing 00289.png
# Processing 2D-scatter_84.png
# Processing 00000.png
# Processing 00201.png
# Processing 00181.png
# Processing 00045.png
# Processing 2D-scatter_9.png
# Processing 00133.png
# All done
# Processing line_72.png
# Processing line_129.png
# Processing 00172.png
# Processing line_104.png
# Processing 00277.png
# Processing line_145.png
# Processing 00028.png
# Processing 00066.png
# Processing 00073.png
# Processing 00139.png
# Processing 00303.png
# Processing 00276.png
# Processing 00302.png
# Processing 00036.png
# Processing line_114.png
# Processing 00055.png
# Processing line_77.png
# Processing line_115.png
# Processing 00114.png
# Processing 00016.png
# Processing 00188.png
# Processing line_5.png
# Processing 00079.png
# Processing 00261.png
# Processing 00007.png
# Processing 00305.png
# Processing 00077.png
# Processing 00219.png
# Processing 00129.png
# Processing line_119.png
# Processing 00248.png
# Processing 00183.png
# Processing line_83.png
# Processing 00208.png
# Processing 00091.png
# Processing line_147.png
# Processing 00169.png
# Processing 00297.png
# Processing 00236.png
# Processing 00026.png
# Processing 00043.png
# Processing line_144.png
# Processing line_29.png
# Processing 00182.png
# Processing 00230.png
# Processing 00222.png
# Processing 00108.png
# Processing line_2.png
# Processing 00179.png
# Processing 00206.png
# Processing 00086.png
# Processing 00286.png
# Processing line_6.png
# Processing 00003.png
# Processing 00162.png
# Processing 00023.png
# Processing 00160.png
# Processing 00178.png
# Processing 00064.png
# Processing line_134.png
# Processing 00296.png
# Processing line_85.png
# Processing line_149.png
# Processing 00151.png
# Processing 00102.png
# Processing line_80.png
# Processing 00156.png
# Processing line_51.png
# Processing 00310.png
# Processing 00126.png
# Processing 00047.png
# Processing line_71.png
# Processing 00083.png
# Processing line_0.png
# Processing line_44.png
# Processing 00099.png
# Processing 00127.png
# Processing 00044.png
# Processing 00287.png
# Processing 00134.png
# Processing 00164.png
# Processing 00154.png
# Processing line_123.png
# Processing 00171.png
# Processing 00282.png
# Processing line_137.png
# Processing 00213.png
# Processing 00193.png
# Processing 00255.png
# Processing line_69.png
# Processing 00150.png
# Processing line_130.png
# Processing 00121.png
# Processing 00281.png
# Processing 00237.png
# Processing 00203.png
# Processing 00010.png
# Processing line_57.png
# Processing 00053.png
# Processing 00019.png
# Processing line_139.png
# Processing 00084.png
# Processing 00165.png
# Processing 00192.png
# Processing 00189.png
# Processing 00177.png
# Processing line_141.png
# Processing 00143.png
# Processing 00231.png
# Processing 00215.png
# Processing line_84.png
# Processing line_19.png
# Processing 00067.png
# Processing 00078.png
# Processing 00093.png
# Processing line_8.png
# Processing 00087.png
# Processing 00052.png
# Processing 00103.png
# Processing 00176.png
# Processing line_41.png
# Processing 00018.png
# Processing 00216.png
# Processing 00283.png
# Processing line_46.png
# Processing line_93.png
# Processing 00194.png
# Processing line_7.png
# Processing line_32.png
# Processing 00300.png
# Processing 00022.png
# Processing 00252.png
# Processing 00267.png
# Processing 00200.png
# Processing line_35.png
# Processing 00293.png
# Processing 00241.png
# Processing 00167.png
# Processing 00138.png
# Processing line_97.png
# Processing line_65.png
# Processing line_82.png
# Processing line_30.png
# Processing 00006.png
# Processing 00311.png
# Processing line_126.png
# Processing 00308.png
# Processing line_55.png
# Processing line_9.png
# Processing line_21.png
# Processing line_150.png
# Processing 00088.png
# Processing 00017.png
# Processing 00227.png
# Processing 00004.png
# Processing line_43.png
# Processing line_111.png
# Processing 00130.png
# Processing 00027.png
# Processing 00125.png
# Processing 00195.png
# Processing 00170.png
# Processing 00039.png
# Processing 00157.png
# Processing 00109.png
# Processing 00190.png
# Processing line_127.png
# Processing line_15.png
# Processing 00153.png
# Processing 00249.png
# Processing line_146.png
# Processing line_131.png
# Processing line_64.png
# Processing 00207.png
# Processing line_66.png
# Processing 00186.png
# Processing 00197.png
# Processing line_103.png
# Processing 00035.png
# Processing line_47.png
# Processing 00011.png
# Processing 00235.png
# Processing 00140.png
# Processing 00145.png
# Processing 00144.png
# Processing 00292.png
# Processing line_135.png
# Processing line_68.png
# Processing 00295.png
# Processing 00316.png
# Processing 00166.png
# Processing line_86.png
# Processing 00081.png
# Processing line_37.png
# Processing 00090.png
# Processing 00229.png
# Processing 00284.png
# Processing 00262.png
# Processing line_106.png
# Processing 00098.png
# Processing 00301.png
# Processing line_54.png
# Processing 00291.png
# Processing line_4.png
# Processing 00089.png
# Processing 00072.png
# Processing 00263.png
# Processing line_81.png
# Processing line_120.png
# Processing 00214.png
# Processing 00119.png
# Processing 00254.png
# Processing 00013.png
# Processing 00069.png
# Processing line_136.png
# Processing line_73.png
# Processing 00224.png
# Processing 00304.png
# Processing 00175.png
# Processing line_122.png
# Processing line_140.png
# Processing line_108.png
# Processing 00163.png
# Processing line_62.png
# Processing 00294.png
# Processing line_78.png
# Processing 00002.png
# Processing line_124.png
# Processing line_105.png
# Processing 00048.png
# Processing 00233.png
# Processing 00247.png
# Processing line_58.png
# Processing 00080.png
# Processing 00015.png
# Processing line_87.png
# Processing 00051.png
# Processing 00221.png
# Processing 00226.png
# Processing 00299.png
# Processing line_102.png
# Processing 00239.png
# Processing line_18.png
# Processing line_52.png
# Processing line_94.png
# Processing line_56.png
# Processing line_112.png
# Processing 00274.png
# Processing 00290.png
# Processing line_125.png
# Processing 00060.png
# Processing 00205.png
# Processing 00100.png
# Processing 00074.png
# Processing line_74.png
# Processing line_11.png
# Processing line_53.png
# Processing 00180.png
# Processing 00021.png
# Processing 00050.png
# Processing 00270.png
# Processing line_88.png
# Processing line_27.png
# Processing line_26.png
# Processing 00104.png
# Processing 00032.png
# Processing 00071.png
# Processing 00096.png
# Processing 00173.png
# Processing 00054.png
# Processing line_76.png
# Processing 00148.png
# Processing 00024.png
# Processing 00038.png
# Processing line_60.png
# Processing 00056.png
# Processing 00240.png
# Processing 00105.png
# Processing 00258.png
# Processing 00009.png
# Processing line_25.png
# Processing 00001.png
# Processing line_90.png
# Processing 00317.png
# Processing 00082.png
# Processing 00257.png
# Processing line_128.png
# Processing line_70.png
# Processing 00202.png
# Processing 00122.png
# Processing line_67.png
# Processing line_63.png
# Processing line_28.png
# Processing line_96.png
# Processing 00030.png
# Processing 00265.png
# Processing 00315.png
# Processing 00313.png
# Processing line_107.png
# Processing 00185.png
# Processing 00223.png
# Processing 00256.png
# Processing 00218.png
# Processing 00113.png
# Processing 00279.png
# Processing 00152.png
# Processing 00101.png
# Processing 00220.png
# Processing 00212.png
# Processing 00314.png
# Processing 00120.png
# Processing 00059.png
# Processing line_101.png
# Processing 00005.png
# Processing line_79.png
# Processing line_117.png
# Processing 00142.png
# Processing 00106.png
# Processing line_50.png
# Processing line_89.png
# Processing 00204.png
# Processing 00123.png
# Processing 00008.png
# Processing 00029.png
# Processing 00266.png
# Processing 00110.png
# Processing 00225.png
# Processing 00250.png
# Processing 00199.png
# Processing 00242.png
# Processing 00146.png
# Processing 00095.png
# Processing 00020.png
# Processing line_48.png
# Processing line_31.png
# Processing line_10.png
# Processing line_14.png
# Processing line_132.png
# Processing 00135.png
# Processing 00136.png
# Processing line_133.png
# Processing line_59.png
# Processing 00025.png
# Processing 00111.png
# Processing line_142.png
# Processing 00040.png
# Processing 00158.png
# Processing 00031.png
# Processing 00269.png
# Processing 00309.png
# Processing 00094.png
# Processing line_92.png
# Processing 00137.png
# Processing line_143.png
# Processing 00280.png
# Processing line_3.png
# Processing 00014.png
# Processing line_138.png
# Processing line_23.png
# Processing 00246.png
# Processing 00264.png
# Processing line_118.png
# Processing 00132.png
# Processing 00211.png
# Processing 00191.png
# Processing 00288.png
# Processing line_42.png
# Processing 00228.png
# Processing line_36.png
# Processing 00041.png
# Processing line_17.png
# Processing 00174.png
# Processing 00076.png
# Processing 00259.png
# Processing 00278.png
# Processing 00268.png
# Processing 00209.png
# Processing 00042.png
# Processing 00245.png
# Processing line_109.png
# Processing 00037.png
# Processing line_13.png
# Processing 00275.png
# Processing 00307.png
# Processing 00234.png
# Processing 00196.png
# Processing 00131.png
# Processing 00063.png
# Processing 00155.png
# Processing line_1.png
# Processing 00012.png
# Processing 00046.png
# Processing line_16.png
# Processing 00062.png
# Processing 00116.png
# Processing line_45.png
# Processing line_91.png
# Processing 00198.png
# Processing 00112.png
# Processing line_34.png
# Processing line_22.png
# Processing 00243.png
# Processing 00107.png
# Processing line_12.png
# Processing 00124.png
# Processing 00271.png
# Processing 00141.png
# Processing 00232.png
# Processing 00118.png
# Processing 00097.png
# Processing 00168.png
# Processing 00061.png
# Processing 00253.png
# Processing 00210.png
# Processing 00068.png
# Processing line_99.png
# Processing line_49.png
# Processing 00033.png
# Processing 00049.png
# Processing line_38.png
# Processing line_75.png
# Processing 00085.png
# Processing line_39.png
# Processing line_100.png
# Processing 00298.png
# Processing line_110.png
# Processing 00272.png
# Processing 00159.png
# Processing line_24.png
# Processing 00057.png
# Processing line_33.png
# Processing 00260.png
# Processing 00117.png
# Processing 00285.png
# Processing 00238.png
# Processing 00244.png
# Processing 00273.png
# Processing 00115.png
# Processing 00184.png
# Processing line_20.png
# Processing 00187.png
# Processing 00034.png
# Processing line_95.png
# Processing line_61.png
# Processing 00092.png
# Processing line_113.png
# Processing 00217.png
# Processing 00149.png
# Processing line_121.png
# Processing 00058.png
# Processing 00161.png
# Processing 00065.png
# Processing 00128.png
# Processing 00306.png
# Processing line_148.png
# Processing line_98.png
# Processing line_40.png
# Processing line_116.png
# Processing 00075.png
# Processing 00070.png
# Processing 00312.png
# Processing 00251.png
# Processing 00147.png
# Processing 00289.png
# Processing 00000.png
# Processing 00201.png
# Processing 00181.png
# Processing 00045.png
# Processing 00133.png
# All done
# Processing pie_68.png
# Processing pie_86.png
# Processing 00172.png
# Processing pie_39.png
# Processing 00028.png
# Processing 00066.png
# Processing pie_101.png
# Processing 00073.png
# Processing 00036.png
# Processing 00055.png
# Processing pie_122.png
# Processing 00114.png
# Processing 00016.png
# Processing 00188.png
# Processing 00079.png
# Processing pie_47.png
# Processing pie_81.png
# Processing pie_34.png
# Processing 00077.png
# Processing 00219.png
# Processing pie_89.png
# Processing 00183.png
# Processing pie_17.png
# Processing pie_115.png
# Processing 00208.png
# Processing 00091.png
# Processing 00169.png
# Processing pie_6.png
# Processing 00236.png
# Processing 00043.png
# Processing pie_90.png
# Processing pie_36.png
# Processing pie_144.png
# Processing 00182.png
# Processing 00230.png
# Processing 00222.png
# Processing 00108.png
# Processing 00179.png
# Processing 00206.png
# Processing 00086.png
# Processing pie_7.png
# Processing 00003.png
# Processing pie_19.png
# Processing 00023.png
# Processing 00178.png
# Processing pie_103.png
# Processing 00151.png
# Processing 00102.png
# Processing 00156.png
# Processing pie_3.png
# Processing 00126.png
# Processing 00047.png
# Processing 00083.png
# Processing pie_38.png
# Processing 00044.png
# Processing 00134.png
# Processing pie_82.png
# Processing 00164.png
# Processing 00154.png
# Processing pie_110.png
# Processing pie_126.png
# Processing pie_137.png
# Processing 00171.png
# Processing pie_71.png
# Processing 00213.png
# Processing 00150.png
# Processing pie_88.png
# Processing pie_141.png
# Processing 00121.png
# Processing pie_60.png
# Processing 00237.png
# Processing 00203.png
# Processing 00010.png
# Processing pie_120.png
# Processing pie_117.png
# Processing pie_104.png
# Processing 00019.png
# Processing pie_133.png
# Processing 00084.png
# Processing 00165.png
# Processing pie_4.png
# Processing 00192.png
# Processing pie_29.png
# Processing 00189.png
# Processing 00177.png
# Processing pie_112.png
# Processing pie_65.png
# Processing 00143.png
# Processing 00231.png
# Processing pie_14.png
# Processing 00215.png
# Processing 00067.png
# Processing 00078.png
# Processing 00087.png
# Processing pie_114.png
# Processing 00103.png
# Processing 00176.png
# Processing 00018.png
# Processing 00216.png
# Processing pie_132.png
# Processing pie_74.png
# Processing 00194.png
# Processing 00022.png
# Processing 00200.png
# Processing 00241.png
# Processing 00138.png
# Processing 00006.png
# Processing pie_57.png
# Processing pie_42.png
# Processing pie_98.png
# Processing 00088.png
# Processing pie_76.png
# Processing pie_87.png
# Processing pie_148.png
# Processing 00017.png
# Processing 00227.png
# Processing 00004.png
# Processing pie_27.png
# Processing 00130.png
# Processing pie_79.png
# Processing 00027.png
# Processing pie_136.png
# Processing pie_53.png
# Processing 00125.png
# Processing pie_123.png
# Processing 00195.png
# Processing 00170.png
# Processing 00157.png
# Processing pie_58.png
# Processing 00109.png
# Processing 00190.png
# Processing pie_91.png
# Processing pie_83.png
# Processing pie_119.png
# Processing 00153.png
# Processing 00207.png
# Processing 00186.png
# Processing 00197.png
# Processing 00035.png
# Processing 00011.png
# Processing pie_70.png
# Processing 00235.png
# Processing pie_143.png
# Processing 00145.png
# Processing 00144.png
# Processing pie_9.png
# Processing pie_32.png
# Processing pie_13.png
# Processing 00166.png
# Processing pie_75.png
# Processing 00081.png
# Processing 00090.png
# Processing 00229.png
# Processing pie_100.png
# Processing 00089.png
# Processing 00072.png
# Processing pie_138.png
# Processing pie_99.png
# Processing pie_52.png
# Processing pie_44.png
# Processing 00214.png
# Processing 00119.png
# Processing 00013.png
# Processing 00224.png
# Processing 00175.png
# Processing pie_21.png
# Processing 00163.png
# Processing pie_64.png
# Processing pie_16.png
# Processing 00002.png
# Processing 00048.png
# Processing pie_62.png
# Processing 00233.png
# Processing pie_127.png
# Processing 00080.png
# Processing pie_12.png
# Processing 00015.png
# Processing pie_1.png
# Processing pie_56.png
# Processing 00051.png
# Processing pie_97.png
# Processing 00221.png
# Processing 00226.png
# Processing pie_73.png
# Processing pie_85.png
# Processing pie_146.png
# Processing 00239.png
# Processing pie_46.png
# Processing 00060.png
# Processing 00205.png
# Processing 00100.png
# Processing 00074.png
# Processing pie_43.png
# Processing pie_63.png
# Processing pie_150.png
# Processing pie_69.png
# Processing pie_147.png
# Processing 00180.png
# Processing 00021.png
# Processing pie_5.png
# Processing 00032.png
# Processing pie_15.png
# Processing 00071.png
# Processing 00096.png
# Processing 00173.png
# Processing 00054.png
# Processing pie_131.png
# Processing pie_50.png
# Processing 00024.png
# Processing pie_49.png
# Processing 00038.png
# Processing 00056.png
# Processing 00105.png
# Processing 00009.png
# Processing pie_129.png
# Processing pie_78.png
# Processing pie_40.png
# Processing 00001.png
# Processing pie_94.png
# Processing pie_130.png
# Processing pie_23.png
# Processing 00082.png
# Processing pie_96.png
# Processing 00202.png
# Processing 00122.png
# Processing pie_41.png
# Processing pie_24.png
# Processing 00030.png
# Processing pie_51.png
# Processing 00185.png
# Processing 00223.png
# Processing pie_66.png
# Processing pie_67.png
# Processing 00218.png
# Processing 00113.png
# Processing pie_80.png
# Processing pie_61.png
# Processing 00152.png
# Processing pie_30.png
# Processing pie_106.png
# Processing 00101.png
# Processing 00220.png
# Processing pie_55.png
# Processing 00212.png
# Processing 00120.png
# Processing pie_93.png
# Processing pie_20.png
# Processing 00059.png
# Processing pie_45.png
# Processing 00005.png
# Processing 00204.png
# Processing 00123.png
# Processing 00008.png
# Processing 00029.png
# Processing 00110.png
# Processing 00225.png
# Processing 00199.png
# Processing 00242.png
# Processing 00095.png
# Processing 00020.png
# Processing pie_26.png
# Processing pie_33.png
# Processing 00135.png
# Processing pie_102.png
# Processing pie_145.png
# Processing pie_31.png
# Processing pie_25.png
# Processing 00111.png
# Processing 00158.png
# Processing 00031.png
# Processing pie_125.png
# Processing 00094.png
# Processing 00137.png
# Processing 00014.png
# Processing pie_59.png
# Processing pie_95.png
# Processing pie_48.png
# Processing pie_124.png
# Processing pie_28.png
# Processing 00211.png
# Processing 00191.png
# Processing pie_84.png
# Processing 00228.png
# Processing 00041.png
# Processing 00174.png
# Processing 00209.png
# Processing 00042.png
# Processing pie_35.png
# Processing pie_18.png
# Processing 00037.png
# Processing pie_135.png
# Processing 00234.png
# Processing 00196.png
# Processing pie_109.png
# Processing 00063.png
# Processing 00155.png
# Processing pie_54.png
# Processing 00012.png
# Processing 00046.png
# Processing 00062.png
# Processing pie_139.png
# Processing 00116.png
# Processing pie_116.png
# Processing pie_108.png
# Processing 00198.png
# Processing 00243.png
# Processing 00107.png
# Processing 00141.png
# Processing 00232.png
# Processing pie_149.png
# Processing pie_2.png
# Processing 00118.png
# Processing 00097.png
# Processing pie_8.png
# Processing 00168.png
# Processing pie_134.png
# Processing 00061.png
# Processing 00210.png
# Processing 00068.png
# Processing pie_105.png
# Processing 00033.png
# Processing pie_0.png
# Processing 00049.png
# Processing pie_128.png
# Processing pie_22.png
# Processing pie_121.png
# Processing 00085.png
# Processing pie_142.png
# Processing pie_107.png
# Processing 00159.png
# Processing 00057.png
# Processing pie_10.png
# Processing 00117.png
# Processing pie_92.png
# Processing pie_140.png
# Processing 00238.png
# Processing 00244.png
# Processing 00115.png
# Processing 00184.png
# Processing 00187.png
# Processing 00034.png
# Processing pie_113.png
# Processing pie_37.png
# Processing 00092.png
# Processing 00217.png
# Processing 00149.png
# Processing 00058.png
# Processing pie_11.png
# Processing 00065.png
# Processing 00128.png
# Processing pie_72.png
# Processing pie_77.png
# Processing 00075.png
# Processing 00070.png
# Processing pie_111.png
# Processing 00147.png
# Processing 00000.png
# Processing 00201.png
# Processing 00181.png
# Processing 00045.png
# Processing pie_118.png
# All done

# %%
def load_data(csv_path):
    image_data = []
    label_data = []
    df = pd.read_csv(csv_path, sep=",", index_col=False)
    data_len = len(df['Image_path'])
    for i in range(data_len):
        temp = cv2.imread(df['Image_path'][i])
        temp = (cv2.cvtColor(temp, cv2.COLOR_BGR2RGB)).tolist()
        image_data.append(temp)
        if df['Class'][i] == 'bar':
            label_data.append([1, 0, 0, 0, 0])
#             label_data.append(1)
        elif df['Class'][i] == 'scatterplot':
            label_data.append([0, 1, 0, 0, 0])
#               label_data.append(2)
        elif df['Class'][i] == 'line':
            label_data.append([0, 0, 1, 0, 0])
#             label_data.append(3)
        elif df['Class'][i] == 'pie':
            label_data.append([0, 0, 0, 1, 0])
#             label_data.append(4)
        else:
            label_data.append([0, 0, 0, 0, 1])
    return (image_data, label_data)

# %%
num_classes = 4
epochs = 3

# %%
X_test, y_test = load_data("/home/komaldadhich/Documents/study/Research/graph_percept/source/project/chart-data-extraction/classifier/Chart_classifier/dataset2/test/labels.csv")

# %%
X_train, y_train = load_data("/home/komaldadhich/Documents/study/Research/graph_percept/source/project/chart-data-extraction/classifier/Chart_classifier/dataset2/train/labels.csv")

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
print(X_test.shape)
print(X_train.shape)
print (y_train[0])
# print len(y_test)
plt.imshow(X_train[0])

# %%
X_train = X_train.reshape(1865,200,200,3)
X_test = X_test.reshape(247,200,200,3)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
# X_test /= 255.0
# y_train = to_categorical(y_train,num_classes)
# y_test = to_categorical(y_test, num_classes)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# %%
cnn = Sequential()
cnn.add(Conv2D(16, kernel_size=(5,5),input_shape=(200,200,3), padding='same', activation='relu', data_format='channels_last'))
cnn.add(Conv2D(16, kernel_size=(5,5), padding='same', activation='relu'))
# cnn.add(Activation('relu'))
# print (cnn.output_shape)
cnn.add(MaxPooling2D())
cnn.add(Conv2D(16, kernel_size=(5,5),padding='same', activation='relu'))
cnn.add(Conv2D(16, kernel_size=(5,5), padding='same', activation='relu'))
# cnn.add(Activation('relu'))
cnn.add(MaxPooling2D())
cnn.add(Conv2D(32, kernel_size=(5,5),padding='same', activation='relu'))
cnn.add(Conv2D(32, kernel_size=(5,5), padding='same', activation='relu'))
# cnn.add(Activation('relu'))
cnn.add(MaxPooling2D())
cnn.add(Conv2D(64, kernel_size=(5,5),padding='same', activation='relu'))
cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu'))
# cnn.add(Activation('relu'))
cnn.add(MaxPooling2D())
cnn.add(Flatten())        
print (cnn.output_shape)
cnn.add(Dense(16, activation='relu'))
# cnn.add(Flatten()) 
# cnn.add(Activation('relu'))
# cnn.add(Dropout(0.25))
cnn.add(Dense(5, activation='softmax'))
cnn.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
cnn.summary()

# %%
history_cnn = cnn.fit(X_train,y_train,epochs=10,verbose=1,validation_data=(X_train,y_train))

# %%
plt.plot(history_cnn.history['acc'])

# %%
plt.plot(history_cnn.history['loss'])

# %%
score = cnn.evaluate(X_test, y_test)

# %%
score

# %%
# serialize model to JSON
model_json = cnn.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
cnn.save_weights("model.h5")
print("Saved model to disk")

# %%
from numpy import loadtxt
from keras.models import load_model
from keras.models import model_from_json

# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
loaded_model.summary()
# Out:
# Using TensorFlow backend.
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:469: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:470: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:471: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:472: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:473: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:476: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/komaldadhich/Documents/study/Research/graph_percept/Chart-Image-Classification/venv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Loaded model from disk
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 200, 200, 16)      1216
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 200, 200, 16)      6416
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 100, 100, 16)      6416
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 100, 100, 16)      6416
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 50, 50, 32)        12832
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 50, 50, 32)        25632
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 25, 25, 64)        51264
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 25, 25, 64)        102464
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                147472
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 85
# =================================================================
# Total params: 360,213
# Trainable params: 360,213
# Non-trainable params: 0
# _________________________________________________________________

# %%
# image = cv2.imread("/home/komaldadhich/Documents/study/Research/graph_percept/source/project/chart_percept/charts/bars/bc01/bc01-src.png")
# image = cv2.imread("/home/komaldadhich/Desktop/point4.png")
# image = cv2.imread("/home/komaldadhich/Desktop/download_bar2.png")
# image = cv2.imread("/home/komaldadhich/Desktop/simple_bar.png")
# image = cv2.imread("/home/komaldadhich/Desktop/images.png")
# image = cv2.imread("/home/komaldadhich/Desktop/stacked.png")

# image = cv2.imread("/home/komaldadhich/Desktop/line5.jpeg")
# image = cv2.imread("/home/komaldadhich/Desktop/pie4.jpeg")

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
#
# image = Image.open("/home/komaldadhich/Documents/study/Research/graph_percept/source/project/chart-data-extraction/classifier/Chart_classifier/bartype/horizontal_simple_bar/bar1.png")
# image = Image.open("/home/komaldadhich/Desktop/images2.png")
image = Image.open("/home/komaldadhich/Documents/study/Research/graph_percept/source/project/chart-data-extraction/Computation-and-visualization-tool/data/bars/bc02/bc02-src.png")
rgb_im = image.convert('RGB')
# image = cv2.resize(image, (200, 200))
print(image.size)
image = rgb_im.resize((200, 200), Image.ANTIALIAS)
plt.imshow(rgb_im)
image = np.asarray(image)
print (image.shape)
image = image[...,:3].reshape(1, 200, 200, 3)
image = image.astype('float32')
image /= 255.0
# Out:
# (640, 480)
# (200, 200, 3)

# %%
# pred = cnn.predict_classes(image)
pred = loaded_model.predict_classes(image)

# %%
pred
# Out:
# array([1])

# %%
loaded_model.predict(image)
# Out:
# array([[1.0995713e-01, 5.1246023e-01, 3.1351092e-01, 6.3979670e-02,
#         9.1917485e-05]], dtype=float32)
